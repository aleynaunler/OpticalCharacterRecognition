# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('kimlik1.jpg',0)
img2 = img.copy()
template = cv2.imread('foto.jpg',0)
w, h = template.shape[::-1]

methods = ['cv2.TM_CCOEFF']

for meth in methods:
    img = img2.copy()
    method = eval(meth)
    
    res = cv2.matchTemplate(img,template,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    if method in ['cv2.TM_CCOEFF']:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)

    cv2.rectangle(img,top_left, bottom_right, 255, 2)
    
    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)

    plt.show()

# %%
cv2.imshow('dnm',template)
cv2.waitKey(0)
# Out:
# -1

# %%
print(w,h)
# Out:
# 152 150

# %%
def shape(temp):
    temp = cv2.imread('tr.jpg',0)
    print("tr",temp.shape)
    temp1 = cv2.imread('ad.jpg',0)
    print("ad",temp1.shape)
    temp2 = cv2.imread('soyad.jpg',0)
    print("soyad",temp2.shape)
    temp3 = cv2.imread('dog.jpg',0)
    print("doğumtarihi",temp3.shape)
    temp4 = cv2.imread('seri.jpg',0)
    print("serino",temp4.shape)
    temp5 = cv2.imread('valid.jpg',0)
    print("valid",temp5.shape)
    temp6 = cv2.imread('cnsy.jpg',0)
    print("cinsiyet",temp6.shape)
    temp7 = cv2.imread('uyr.jpg',0)
    print("uyruk",temp7.shape)
    temp9 = cv2.imread('kod.jpg',0)
    print("kod",temp9.shape)
    temp0 = cv2.imread('tc.jpg',0)
    print("tcno",temp0.shape)

# %%
shape(img2)
# Out:
# tr (80, 600)
# ad (40, 265)
# soyad (40, 260)
# doğumtarihi (35, 230)
# serino (40, 210)
# valid (40, 270)
# cinsiyet (45, 175)
# uyruk (50, 180)
# kod (150, 152)
# tcno (55, 165)
